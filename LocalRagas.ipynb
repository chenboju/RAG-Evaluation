# %%
import ragas

print(ragas.__version__)
# Out:
# 0.2.2.dev9+g8efe80d

# %%
import os

os.environ["OPENAI_API_KEY"] = "your_apikey"

# %%
from langchain_openai import ChatOpenAI 

llm = ChatOpenAI(
    model="gpt-4o-mini"
    )

# %%
from langchain_openai import OpenAIEmbeddings

embeddingModel = OpenAIEmbeddings(
    model="text-embedding-3-small",
    # With the `text-embedding-3` class
    # of models, you can specify the size
    # of the embeddings you want returned.
    # dimensions=1536 #
)

# %%
from langchain.document_loaders import DirectoryLoader

# 載入資料夾中所有TXT檔案
loader = DirectoryLoader('./', glob='**/*.txt')

# 將資料轉成document物佚，每個檔案會為作為一個document
docs = loader.load()
 
docs
# Out:
# The MIME type of '消費者保護法.txt' is "cannot open `\\346\\266\\210\\350\\262\\273\\350\\200\\205\\344\\277\\235\\350\\255\\267\\346\\263\\225.txt' (illegal byte sequence)". This file type is not currently supported in unstructured.
# The MIME type of '消費者保護細則.txt' is "cannot open `\\346\\266\\210\\350\\262\\273\\350\\200\\205\\344\\277\\235\\350\\255\\267\\347\\264\\260\\345\\211\\207.txt' (illegal byte sequence)". This file type is not currently supported in unstructured.
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=600, chunk_overlap=100)
splits = text_splitter.split_documents(docs)

# %%
from langchain_chroma import Chroma
vectorstore = Chroma.from_documents(documents=splits, embedding=embeddingModel )

# %%
retriever = vectorstore.as_retriever()

# %%
from langchain import hub
prompt = hub.pull("rlm/rag-prompt")


def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)
# Out:
# c:\Users\qwe11\anaconda3\envs\RagAS\Lib\site-packages\langchain\hub.py:86: DeprecationWarning: The `langchainhub sdk` is deprecated.
# Please use the `langsmith sdk` instead:
#   pip install langsmith
# Use the `pull_prompt` method.
#   res_dict = client.pull_repo(owner_repo_commit)

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# rag_chain.invoke("消費者保護法第七條所規定之責任是否為『無過失責任』？")

# %%
# from datasets import Dataset
 
# questions = ["為預防消費糾紛,保護消費者權益,中央主管機關得選擇特定行業,擬訂其定型化契約應記載或不得記載事項,報請行政院核定後公告,下列敘述何者錯誤?(A)公告不得記載之事項,經記載於定型化契約,仍構成契約之內容(B)違反公告之定型化契約,其定型化契約條款無效(C)公告應記載之事項,雖未記載於定型化契約,仍構成契約之內容(D)企業經營者使用定型化契約者,主管機關得隨時派員查核", 
#              "依消費者保護法規定,下列關於企業經營者提供商品之敘述,何者正確?(A)對於有危害消費者財產之虞的商品,僅負於明顯處為警告標示之義務(B)對於第三人的損害賠償責任,得預先約定免除(C)對於消費者的損害賠償責任,得預先約定限制(D)對於有事實足認有危害消費者安全與健康之虞的商品,應即回收",
#              "依消費者保護法規定,企業經營者以定型化契約條款使消費者拋棄消費者審閱之合理期間,其契約條款之效力如何?(A)消費者不得主張該條款仍構成契約之內容(B)其條款不構成契約之內容(C)由行政院消費者保護處審定(D)由目的事業主管機關得撤銷",
#              "依消費者保護法規定,下列有關消費者保護團體之敘述,何者錯誤?(A)消費者保護團體以社團法人或財團法人為限(B)以保護消費者權益、推行消費者教育為宗旨(C)消費者保護刊物之編印發行為其任務之一(D)以確保公平競爭、促進經濟之安定與繁榮為宗旨",
#              "依消費者保護法規定關於商品標示,下列敘述何者錯誤?(A)企業經營者應依商品標示法等法令為商品之標示(B)輸入之商品,應附中文標示及說明書(C)輸入之商品,所附中文標示及說明書,其內容得就原產地之標示及說明,簡略摘要之(D)輸入之商品或服務在原產地附有警告標示者,應附中文標示及說明書,其內容不得較原產地之標示及說明書簡略",
#              "依消費者保護法規定,企業經營者所出具之書面保證書其應載明事項,下列何者錯誤?(A)交易日期(B)製造商之資本額(C)保證之內容(D)製造商之名稱、地址",
#              "依消費者保護法規定,下列有關消費者保護團體從事檢驗之敘述,何者錯誤?(A)得委託設有與檢驗項目有關之檢驗設備之機關、團體檢驗(B)檢驗結果有錯誤時,應主動對外更正(C)發表檢驗結果後,通知相關企業經營者,得不公布其檢驗方法及經過(D)為從事商品或服務檢驗,應設置與檢驗項目有關之檢驗設備",
#              "依消費者保護法規定,有關消費關係之定義,下列敘述何者正確?(A)指消費者與消費者間就商品所發生之法律關係(B)指企業經營者與企業就商品製作所發生之法律關係(C)指企業經營者與企業經營者間就商品所發生之法律關係(D)指消費者與企業經營者間就商品或服務所發生之法律關係",
#              "依消費者保護法規定,下列關於定型化契約條款之敘述,何者錯誤?(A)定型化契約條款未經記載於定型化契約中而依正常情形顯非消費者所得預見者,該條款不構成契約之內容(B)契約中之定型化契約條款牴觸個別磋商條款之約定者,其牴觸部分無效(C)定型化契約中之定型化契約條款,不構成契約內容之一部者,除去該部分,該契約之其他部分,仍為有效(D)定型化契約中之定型化契約條款,一部無效,該契約全部無效",
#              "依消費者保護法規定,提供之商品或服務具有危害消費者健康、財產之可能者,下列何者應於明顯處為警告標示及緊急處理危險之方法?(A)企業經營者(B)目的事業主管機關(C)行政院消費者保護處(D)消費者"
#             ]
# ground_truths = [["公告不得記載之事項,經記載於定型化契約"],
#                 ["對於有事實足認有危害消費者安全與健康之虞的商品,應即回收"],
#                  ["其條款不構成契約之內容"],
#                  ["以確保公平競爭、促進經濟之安定與繁榮為宗旨"],
#                  ["輸入之商品,所附中文標示及說明書,其內容得就原產地之標示及說明,簡略摘要之"],
#                  ["製造商之資本額"],
#                  ["發表檢驗結果後,通知相關企業經營者,得不公布其檢驗方法及經過"],
#                  ["指企業經營者與企業經營者間就商品所發生之法律關係"],
#                  ["定型化契約中之定型化契約條款,一部無效,該契約全部無效"],
#                 ["企業經營者"]]
# answers = [
#     [
#         """根據消費者保護法的相關規定，以下是對於選項的分析：",
#         "(A) 公告不得記載之事項，經記載於定型化契約，仍構成契約之內容。這是錯誤的，因為如果公告中明確規定不得記載的事項被記載於定型化契約中，則該條款不構成契約內容，消費者可以主張不受該條款的拘束。",
#         "(B) 違反公告之定型化契約，其定型化契約條款無效。這是正確的，因為根據法律規定，違反公告的定型化契約條款會被視為無效。",
#         "(C) 公告應記載之事項，雖未記載於定型化契約，仍構成契約之內容。這是正確的，因為如果公告中要求記載的事項未被記載，則該事項仍然構成契約的一部分。",
#         "(D) 企業經營者使用定型化契約者，主管機關得隨時派員查核。這是正確的，主管機關有權對使用定型化契約的企業進行查核。",
#         "因此，根據上述分析，選項 (A) 是錯誤的。"""
#     ],[
#         "根據消費者保護法的規定，企業經營者在提供商品時有多項法律責任。以下是對於選項的分析：",
#         "(A) 對於有危害消費者財產之虞的商品，僅負於明顯處為警告標示之義務：這一說法不正確。根據消費者保護法，企業經營者必須在商品上附載警告標示，以提醒消費者注意潛在的危險，並不僅限於明顯處。",
#         "(B) 對於第三人的損害賠償責任，得預先約定免除：這一說法不正確。根據消費者保護法第十條之一的規定，企業經營者對消費者或第三人的損害賠償責任不得預先約定限制或免除。",
#         "(C) 對於消費者的損害賠償責任，得預先約定限制：這一說法同樣不正確。根據消費者保護法的相關規定，企業經營者對消費者的損害賠償責任不得預先約定限制。",
#         "(D) 對於有事實足認有危害消費者安全與健康之虞的商品，應即回收：這一說法是正確的。根據消費者保護法第十條的規定，企業經營者在發現其提供的商品可能危害消費者安全與健康時，應立即回收該商品。",
#         "因此，正確的選項是 (D)。"
#     ],[
#     "根據消費者保護法的規定，企業經營者若以定型化契約條款使消費者拋棄消費者審閱之合理期間，該契約條款的效力會受到影響。",
#     "具體來說，根據法律規定，這樣的條款將被視為無效，消費者仍然可以主張該條款不構成契約的內容。",
#     "因此，正確的選項是 (B) 其條款不構成契約之內容。",
#     "這一點強調了消費者在面對不公平的契約條款時，法律提供的保護機制，確保消費者的權益不會因為不平等的契約條款而受到損害。",
#     "這一法律框架的設立，旨在維護消費者的基本權益，並促進公平交易的環境，防止企業利用其優勢地位來剝奪消費者的合法權利。"
#     ],[
#     "根據消費者保護法的規定，消費者保護團體的主要任務是保護消費者權益和推行消費者教育。",
#     "這些團體必須以社團法人或財團法人形式存在，並且其任務之一包括編印和發行消費者保護刊物。",
#     "在您提供的選項中，選項 (D) '以確保公平競爭、促進經濟之安定與繁榮為宗旨' 是錯誤的。",
#     "消費者保護團體的宗旨主要集中在保護消費者權益，而不是直接以促進經濟的安定與繁榮為目的。",
#     "因此，正確的答案是 (D)。"
#     ],[
#     "根據消費者保護法的規定，商品標示的相關要求如下：",
#     "1. 企業經營者的標示義務：企業經營者必須依據商品標示法及其他相關法令進行商品的標示，這是正確的。",
#     "2. 輸入商品的標示要求：輸入商品必須附有中文標示及說明書，這也是正確的。",
#     "3. 內容摘要的要求：輸入商品所附的中文標示及說明書內容不得簡略摘要原產地的標示及說明，這是錯誤的。根據法律規定，這些內容必須完整且不得簡略。",
#     "4. 警告標示的要求：如果輸入商品或服務在原產地附有警告標示，則必須附上中文標示及說明書，且其內容不得簡略，這是正確的。",
#     "因此，選項 (C) 是錯誤的敘述，因為輸入商品的中文標示及說明書內容不得簡略摘要原產地的標示及說明。"
#     ],[
#     "根據消費者保護法的規定，企業經營者在出具書面保證書時，必須載明特定的事項。這些事項包括：",
#     "1. 商品或服務的名稱、種類、數量。",
#     "2. 保證的內容。",
#     "3. 保證期間及其起算方法。",
#     "4. 製造商的名稱和地址。",
#     "5. 由經銷商售出者的名稱和地址。",
#     "6. 交易日期。",
#     "在您提供的選項中，選項 (B) 製造商之資本額並不是書面保證書中必須載明的事項。因此，這個選項是錯誤的。",
#     "總結來說，正確答案是 (B) 製造商之資本額，因為這並不在消費者保護法所要求的書面保證書的內容之內。"
#     ],[
#     "根據消費者保護法的規定，消費者保護團體在從事商品或服務檢驗時，必須遵循特定的原則和程序。以下是對於選項的分析：",
#     "(A) 得委託設有與檢驗項目有關之檢驗設備之機關、團體檢驗：這是正確的，消費者保護團體可以委託其他具備檢驗設備的機關或團體進行檢驗。",
#     "(B) 檢驗結果有錯誤時，應主動對外更正：這也是正確的，消費者保護團體在發現檢驗結果錯誤時，必須主動更正並通知相關方。",
#     "(C) 發表檢驗結果後，通知相關企業經營者，得不公布其檢驗方法及經過：這是錯誤的。根據規定，消費者保護團體在發表檢驗結果後，應公布其檢驗方法及經過，以確保透明度和信任。",
#     "(D) 為從事商品或服務檢驗，應設置與檢驗項目有關之檢驗設備：這是正確的，消費者保護團體必須具備相關的檢驗設備來進行檢驗。",
#     "因此，選項 (C) 是錯誤的。消費者保護團體在發表檢驗結果後，必須公布檢驗方法及經過，以確保檢驗的透明性和公正。"
#     ],[
#     "根據消費者保護法的規定，消費關係的定義是指消費者與企業經營者之間就商品或服務所發生的法律關係。",
#     "因此，正確的敘述是：",
#     "(D) 指消費者與企業經營者間就商品或服務所發生之法律關係。",
#     "這一點強調了消費者在與企業經營者進行交易時所享有的權利和法律保護，確保他們在市場中的利益得到保障。",
#     "消費者保護法的核心目的是為了防止不公平的商業行為，並提供消費者必要的法律支持和救濟途徑，以維護其權益。"
#     ],[
#     "根據消費者保護法的規定，對於定型化契約條款的敘述中，選項 (D) 是錯誤的。以下是對各選項的分析：",
#     "選項分析",
#     "(A) 定型化契約條款未經記載於定型化契約中而依正常情形顯非消費者所得預見者，該條款不構成契約之內容。",
#     "此選項是正確的，因為如果條款未被明確記載，且消費者無法預見，則該條款不會構成契約內容。",
#     "(B) 契約中之定型化契約條款牴觸個別磋商條款之約定者，其牴觸部分無效。",
#     "此選項也是正確的，根據消費者保護法，定型化契約條款與個別磋商條款發生衝突時，牴觸部分無效。",
#     "(C) 定型化契約中之定型化契約條款，不構成契約內容之一部者，除去該部分，該契約之其他部分，仍為有效。",
#     "此選項正確，因為如果某部分條款無效，其他部分仍然可以有效。",
#     "(D) 定型化契約中之定型化契約條款，一部無效，該契約全部無效。",
#     "此選項是錯誤的，因為根據法律規定，只有牴觸部分無效，契約的其他部分仍然有效。",
#     "結論",
#     "因此，根據上述分析，選項 (D) 是錯誤的，因為它誤解了定型化契約條款的法律效力。這一點在消費者保護法中有明確的規定，確保消費者的權益不會因為某一條款的無效而導致整個契約失效。"
#     ],[
#     "根據《消費者保護法》的規定，當提供的商品或服務可能對消費者的健康或財產造成危害時，應由企業經營者在明顯處標示警告，並提供緊急處理危險的方法。",
#     "因此，正確的選擇是：",
#     "(A) 企業經營者",
#     "這一規定旨在確保消費者在使用商品或服務時能夠獲得必要的安全資訊，從而減少潛在的風險和損害。",
#     "企業經營者的責任包括在產品上清楚標示任何可能的危險，並提供相應的應對措施，以保護消費者的安全和權益。"
#     ]
# ]
# contexts = []
 
# # Inference
# for query in questions:
#     contexts.append([docs.page_content for docs in retriever.get_relevant_documents(query)])
 
# # To dict
# data = {
#     "question": questions,
#     "answer": answers,
#     "contexts": contexts,
#     "ground_truths": ground_truths,
#     "reference": [" ".join(gt) if isinstance(gt, list) else gt for gt in ground_truths] 

# }
 
# # Convert dict to dataset
# dataset = Dataset.from_dict(data)

# %%
from datasets import Dataset
 
questions = ["為預防消費糾紛,保護消費者權益,中央主管機關得選擇特定行業,擬訂其定型化契約應記載或不得記載事項,報請行政院核定後公告,下列敘述何者錯誤?(A)公告不得記載之事項,經記載於定型化契約,仍構成契約之內容(B)違反公告之定型化契約,其定型化契約條款無效(C)公告應記載之事項,雖未記載於定型化契約,仍構成契約之內容(D)企業經營者使用定型化契約者,主管機關得隨時派員查核", 
             "依消費者保護法規定,下列關於企業經營者提供商品之敘述,何者正確?(A)對於有危害消費者財產之虞的商品,僅負於明顯處為警告標示之義務(B)對於第三人的損害賠償責任,得預先約定免除(C)對於消費者的損害賠償責任,得預先約定限制(D)對於有事實足認有危害消費者安全與健康之虞的商品,應即回收",
             "依消費者保護法規定,企業經營者以定型化契約條款使消費者拋棄消費者審閱之合理期間,其契約條款之效力如何?(A)消費者不得主張該條款仍構成契約之內容(B)其條款不構成契約之內容(C)由行政院消費者保護處審定(D)由目的事業主管機關得撤銷",
             "依消費者保護法規定,下列有關消費者保護團體之敘述,何者錯誤?(A)消費者保護團體以社團法人或財團法人為限(B)以保護消費者權益、推行消費者教育為宗旨(C)消費者保護刊物之編印發行為其任務之一(D)以確保公平競爭、促進經濟之安定與繁榮為宗旨",
             "依消費者保護法規定關於商品標示,下列敘述何者錯誤?(A)企業經營者應依商品標示法等法令為商品之標示(B)輸入之商品,應附中文標示及說明書(C)輸入之商品,所附中文標示及說明書,其內容得就原產地之標示及說明,簡略摘要之(D)輸入之商品或服務在原產地附有警告標示者,應附中文標示及說明書,其內容不得較原產地之標示及說明書簡略",
             "依消費者保護法規定,企業經營者所出具之書面保證書其應載明事項,下列何者錯誤?(A)交易日期(B)製造商之資本額(C)保證之內容(D)製造商之名稱、地址",
             "依消費者保護法規定,下列有關消費者保護團體從事檢驗之敘述,何者錯誤?(A)得委託設有與檢驗項目有關之檢驗設備之機關、團體檢驗(B)檢驗結果有錯誤時,應主動對外更正(C)發表檢驗結果後,通知相關企業經營者,得不公布其檢驗方法及經過(D)為從事商品或服務檢驗,應設置與檢驗項目有關之檢驗設備",
             "依消費者保護法規定,有關消費關係之定義,下列敘述何者正確?(A)指消費者與消費者間就商品所發生之法律關係(B)指企業經營者與企業就商品製作所發生之法律關係(C)指企業經營者與企業經營者間就商品所發生之法律關係(D)指消費者與企業經營者間就商品或服務所發生之法律關係",
             "依消費者保護法規定,下列關於定型化契約條款之敘述,何者錯誤?(A)定型化契約條款未經記載於定型化契約中而依正常情形顯非消費者所得預見者,該條款不構成契約之內容(B)契約中之定型化契約條款牴觸個別磋商條款之約定者,其牴觸部分無效(C)定型化契約中之定型化契約條款,不構成契約內容之一部者,除去該部分,該契約之其他部分,仍為有效(D)定型化契約中之定型化契約條款,一部無效,該契約全部無效",
             "依消費者保護法規定,提供之商品或服務具有危害消費者健康、財產之可能者,下列何者應於明顯處為警告標示及緊急處理危險之方法?(A)企業經營者(B)目的事業主管機關(C)行政院消費者保護處(D)消費者"
            ]
ground_truths = [["公告不得記載之事項,經記載於定型化契約"],
                ["對於有事實足認有危害消費者安全與健康之虞的商品,應即回收"],
                 ["其條款不構成契約之內容"],
                 ["以確保公平競爭、促進經濟之安定與繁榮為宗旨"],
                 ["輸入之商品,所附中文標示及說明書,其內容得就原產地之標示及說明,簡略摘要之"],
                 ["製造商之資本額"],
                 ["發表檢驗結果後,通知相關企業經營者,得不公布其檢驗方法及經過"],
                 ["指企業經營者與企業經營者間就商品所發生之法律關係"],
                 ["定型化契約中之定型化契約條款,一部無效,該契約全部無效"],
                ["企業經營者"]]
answers = [
    [
        """根據消費者保護法的相關規定，以下是對於選項的分析：",
        "(A) 公告不得記載之事項，經記載於定型化契約，仍構成契約之內容。這是錯誤的，因為如果公告中明確規定不得記載的事項被記載於定型化契約中，則該條款不構成契約內容，消費者可以主張不受該條款的拘束。",
        "(B) 違反公告之定型化契約，其定型化契約條款無效。這是正確的，因為根據法律規定，違反公告的定型化契約條款會被視為無效。",
        "(C) 公告應記載之事項，雖未記載於定型化契約，仍構成契約之內容。這是正確的，因為如果公告中要求記載的事項未被記載，則該事項仍然構成契約的一部分。",
        "(D) 企業經營者使用定型化契約者，主管機關得隨時派員查核。這是正確的，主管機關有權對使用定型化契約的企業進行查核。",
        "因此，根據上述分析，選項 (A) 是錯誤的。"""
    ],[
        "根據消費者保護法的規定，企業經營者在提供商品時有多項法律責任。以下是對於選項的分析：",
        "(A) 對於有危害消費者財產之虞的商品，僅負於明顯處為警告標示之義務：這一說法不正確。根據消費者保護法，企業經營者必須在商品上附載警告標示，以提醒消費者注意潛在的危險，並不僅限於明顯處。",
        "(B) 對於第三人的損害賠償責任，得預先約定免除：這一說法不正確。根據消費者保護法第十條之一的規定，企業經營者對消費者或第三人的損害賠償責任不得預先約定限制或免除。",
        "(C) 對於消費者的損害賠償責任，得預先約定限制：這一說法同樣不正確。根據消費者保護法的相關規定，企業經營者對消費者的損害賠償責任不得預先約定限制。",
        "(D) 對於有事實足認有危害消費者安全與健康之虞的商品，應即回收：這一說法是正確的。根據消費者保護法第十條的規定，企業經營者在發現其提供的商品可能危害消費者安全與健康時，應立即回收該商品。",
        "因此，正確的選項是 (D)。"
    ],[
    "根據消費者保護法的規定，企業經營者若以定型化契約條款使消費者拋棄消費者審閱之合理期間，該契約條款的效力會受到影響。",
    "具體來說，根據法律規定，這樣的條款將被視為無效，消費者仍然可以主張該條款不構成契約的內容。",
    "因此，正確的選項是 (B) 其條款不構成契約之內容。",
    "這一點強調了消費者在面對不公平的契約條款時，法律提供的保護機制，確保消費者的權益不會因為不平等的契約條款而受到損害。",
    "這一法律框架的設立，旨在維護消費者的基本權益，並促進公平交易的環境，防止企業利用其優勢地位來剝奪消費者的合法權利。"
    ],[
    "根據消費者保護法的規定，消費者保護團體的主要任務是保護消費者權益和推行消費者教育。",
    "這些團體必須以社團法人或財團法人形式存在，並且其任務之一包括編印和發行消費者保護刊物。",
    "在您提供的選項中，選項 (D) '以確保公平競爭、促進經濟之安定與繁榮為宗旨' 是錯誤的。",
    "消費者保護團體的宗旨主要集中在保護消費者權益，而不是直接以促進經濟的安定與繁榮為目的。",
    "因此，正確的答案是 (D)。"
    ],[
    "根據消費者保護法的規定，商品標示的相關要求如下：",
    "1. 企業經營者的標示義務：企業經營者必須依據商品標示法及其他相關法令進行商品的標示，這是正確的。",
    "2. 輸入商品的標示要求：輸入商品必須附有中文標示及說明書，這也是正確的。",
    "3. 內容摘要的要求：輸入商品所附的中文標示及說明書內容不得簡略摘要原產地的標示及說明，這是錯誤的。根據法律規定，這些內容必須完整且不得簡略。",
    "4. 警告標示的要求：如果輸入商品或服務在原產地附有警告標示，則必須附上中文標示及說明書，且其內容不得簡略，這是正確的。",
    "因此，選項 (C) 是錯誤的敘述，因為輸入商品的中文標示及說明書內容不得簡略摘要原產地的標示及說明。"
    ],[
    "根據消費者保護法的規定，企業經營者在出具書面保證書時，必須載明特定的事項。這些事項包括：",
    "1. 商品或服務的名稱、種類、數量。",
    "2. 保證的內容。",
    "3. 保證期間及其起算方法。",
    "4. 製造商的名稱和地址。",
    "5. 由經銷商售出者的名稱和地址。",
    "6. 交易日期。",
    "在您提供的選項中，選項 (B) 製造商之資本額並不是書面保證書中必須載明的事項。因此，這個選項是錯誤的。",
    "總結來說，正確答案是 (B) 製造商之資本額，因為這並不在消費者保護法所要求的書面保證書的內容之內。"
    ],[
    "根據消費者保護法的規定，消費者保護團體在從事商品或服務檢驗時，必須遵循特定的原則和程序。以下是對於選項的分析：",
    "(A) 得委託設有與檢驗項目有關之檢驗設備之機關、團體檢驗：這是正確的，消費者保護團體可以委託其他具備檢驗設備的機關或團體進行檢驗。",
    "(B) 檢驗結果有錯誤時，應主動對外更正：這也是正確的，消費者保護團體在發現檢驗結果錯誤時，必須主動更正並通知相關方。",
    "(C) 發表檢驗結果後，通知相關企業經營者，得不公布其檢驗方法及經過：這是錯誤的。根據規定，消費者保護團體在發表檢驗結果後，應公布其檢驗方法及經過，以確保透明度和信任。",
    "(D) 為從事商品或服務檢驗，應設置與檢驗項目有關之檢驗設備：這是正確的，消費者保護團體必須具備相關的檢驗設備來進行檢驗。",
    "因此，選項 (C) 是錯誤的。消費者保護團體在發表檢驗結果後，必須公布檢驗方法及經過，以確保檢驗的透明性和公正。"
    ],[
    "根據消費者保護法的規定，消費關係的定義是指消費者與企業經營者之間就商品或服務所發生的法律關係。",
    "因此，正確的敘述是：",
    "(D) 指消費者與企業經營者間就商品或服務所發生之法律關係。",
    "這一點強調了消費者在與企業經營者進行交易時所享有的權利和法律保護，確保他們在市場中的利益得到保障。",
    "消費者保護法的核心目的是為了防止不公平的商業行為，並提供消費者必要的法律支持和救濟途徑，以維護其權益。"
    ],[
    "根據消費者保護法的規定，對於定型化契約條款的敘述中，選項 (D) 是錯誤的。以下是對各選項的分析：",
    "選項分析",
    "(A) 定型化契約條款未經記載於定型化契約中而依正常情形顯非消費者所得預見者，該條款不構成契約之內容。",
    "此選項是正確的，因為如果條款未被明確記載，且消費者無法預見，則該條款不會構成契約內容。",
    "(B) 契約中之定型化契約條款牴觸個別磋商條款之約定者，其牴觸部分無效。",
    "此選項也是正確的，根據消費者保護法，定型化契約條款與個別磋商條款發生衝突時，牴觸部分無效。",
    "(C) 定型化契約中之定型化契約條款，不構成契約內容之一部者，除去該部分，該契約之其他部分，仍為有效。",
    "此選項正確，因為如果某部分條款無效，其他部分仍然可以有效。",
    "(D) 定型化契約中之定型化契約條款，一部無效，該契約全部無效。",
    "此選項是錯誤的，因為根據法律規定，只有牴觸部分無效，契約的其他部分仍然有效。",
    "結論",
    "因此，根據上述分析，選項 (D) 是錯誤的，因為它誤解了定型化契約條款的法律效力。這一點在消費者保護法中有明確的規定，確保消費者的權益不會因為某一條款的無效而導致整個契約失效。"
    ],[
    "根據《消費者保護法》的規定，當提供的商品或服務可能對消費者的健康或財產造成危害時，應由企業經營者在明顯處標示警告，並提供緊急處理危險的方法。",
    "因此，正確的選擇是：",
    "(A) 企業經營者",
    "這一規定旨在確保消費者在使用商品或服務時能夠獲得必要的安全資訊，從而減少潛在的風險和損害。",
    "企業經營者的責任包括在產品上清楚標示任何可能的危險，並提供相應的應對措施，以保護消費者的安全和權益。"
    ]
]
contexts = []

for query in questions:
    # 使用 retriever 获取相关文档
    docs = retriever.get_relevant_documents(query)
    # 提取文档内容
    context = [doc.page_content for doc in docs]
    # 将上下文添加到列表
    contexts.append(context)

# 将答案和标准答案列表中的内容合并为字符串
answers = ["\n".join(ans) if isinstance(ans, list) else ans for ans in answers]
ground_truths = [" ".join(gt) if isinstance(gt, list) else gt for gt in ground_truths]

# 准备数据字典
data = {
    "question": questions,
    "answer": answers,
    "ground_truth": ground_truths,
    "retrieved_contexts": contexts,
}

# 将数据字典转换为数据集
dataset = Dataset.from_dict(data)

# %%
# from ragas.metrics._faithfulness import faithfulness
# from ragas.metrics._answer_relevancy import answer_relevancy
# from ragas.vancemetrics._answer_rele

# %%
#openai的结果
import os
from ragas import evaluate
from ragas.metrics import (
    faithfulness,
    answer_relevancy,
    context_recall,
    context_precision,
)

 
result = evaluate(
    dataset = dataset, 
    metrics=[
        context_precision,
        context_recall,
        faithfulness,
        answer_relevancy,
    ],
    column_map={
        "question": "question",
        "answer": "answer",
        "ground_truth": "ground_truth",
        "retrieved_contexts": "retrieved_contexts",
    },
)


 
# df = result.to_pandas()
# df
# Out:
# Evaluating:   0%|          | 0/40 [00:00<?, ?it/s]
# D:\RAGAS\ragas\src\ragas\metrics\base.py:281: DeprecationWarning: The function _single_turn_ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextRecall instead.
#   self._single_turn_ascore(sample=sample, callbacks=group_cm),
# D:\RAGAS\ragas\src\ragas\metrics\base.py:281: DeprecationWarning: The function _single_turn_ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextRecall instead.
#   self._single_turn_ascore(sample=sample, callbacks=group_cm),
# D:\RAGAS\ragas\src\ragas\metrics\base.py:281: DeprecationWarning: The function _single_turn_ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextRecall instead.
#   self._single_turn_ascore(sample=sample, callbacks=group_cm),
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

 
df = result.to_pandas()
df

# 創建一個 DataFrame
# df = pd.DataFrame(data)
# df
# Out:
#                                           user_input  \
# 0  為預防消費糾紛,保護消費者權益,中央主管機關得選擇特定行業,擬訂其定型化契約應記載或不得記載...
# 1  依消費者保護法規定,下列關於企業經營者提供商品之敘述,何者正確?(A)對於有危害消費者財產之...
# 2  依消費者保護法規定,企業經營者以定型化契約條款使消費者拋棄消費者審閱之合理期間,其契約條款之...
# 3  依消費者保護法規定,下列有關消費者保護團體之敘述,何者錯誤?(A)消費者保護團體以社團法人或...
# 4  依消費者保護法規定關於商品標示,下列敘述何者錯誤?(A)企業經營者應依商品標示法等法令為商品...
# 5  依消費者保護法規定,企業經營者所出具之書面保證書其應載明事項,下列何者錯誤?(A)交易日期(...
# 6  依消費者保護法規定,下列有關消費者保護團體從事檢驗之敘述,何者錯誤?(A)得委託設有與檢驗項...
# 7  依消費者保護法規定,有關消費關係之定義,下列敘述何者正確?(A)指消費者與消費者間就商品所發...
# 8  依消費者保護法規定,下列關於定型化契約條款之敘述,何者錯誤?(A)定型化契約條款未經記載於定...
# 9  依消費者保護法規定,提供之商品或服務具有危害消費者健康、財產之可能者,下列何者應於明顯處為警...
#
#                                   retrieved_contexts  \
# 0  [中央主管機關為預防消費糾紛，保護消費者權益，促進定型化契約之公平化，得選擇特定行業，擬訂其...
# 1  [Q:028.企業經營者依消費者保護法第七條第三項規定對消費者或第三人之損害賠償責任，得否預...
# 2  [（三）違反合理審閱期間之效力：企業經營者如違反有關合理審閱期間之規定者，由於影響消費者無法...
# 3  [輸入之商品或服務在原產地附有警告標示者，準用前項之規定。\n\n第二十五條（書面保證書及其...
# 4  [企業經營者應確保廣告內容之真實，其對消費者所負之義務不得低於廣告之內容。\n\n企業經營者...
# 5  [（三）廣告代理業：依照公平交易法第二十一條第四項規定，廣告代理業在明知或可得知的情況下，仍...
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# # 創建一個 DataFrame
# df = pd.DataFrame(data)

# 創建視覺化，顯示每個特性的分數變化
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
fig.suptitle("Evaluation Metrics Over 10 Runs", fontsize=16)
# 設置 x 軸為 1 到 10
x_range = range(0, 11)
# y_range = range(1, 11)
# 繪製每個特性的折線圖
df["context_precision"].plot(ax=axes[0, 0], title="Context Precision", color="skyblue",xticks=x_range)
df["context_recall"].plot(ax=axes[0, 1], title="Context Recall", color="lightgreen",xticks=x_range)
df["faithfulness"].plot(ax=axes[1, 0], title="Faithfulness", color="salmon",xticks=x_range)
df["answer_relevancy"].plot(ax=axes[1, 1], title="Answer Relevancy", color="gold",xticks=x_range)

# 設置標籤
for ax in axes.flat:
    ax.set_xlabel("Run")
    ax.set_ylabel("Score")

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# # 生成範例數據，假設有10次評估結果
# data = {
#     "context_precision": np.random.rand(10),
#     "context_recall": np.random.rand(10),
#     "faithfulness": np.random.rand(10),
#     "answer_relevancy": np.random.rand(10),
# }

# # 創建一個 DataFrame
# df = pd.DataFrame(data)

# 創建視覺化，顯示每個特性的分數變化
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
fig.suptitle("Evaluation Metrics Over 10 Runs (Bar Chart)", fontsize=16)

# 設置 x 軸為 1 到 10
x_range = range(1, 11)

# 設置 y 軸的刻度範圍 0.0 到 1.0 並顯示 0.1 的間隔
y_ticks = np.arange(0.0, 1.1, 0.1)

# 繪製每個特性的長條圖，並設置 y 軸範圍和刻度
df["context_precision"].plot(kind="bar", ax=axes[0, 0], title="Context Precision", color="skyblue")
axes[0, 0].set_ylim(0.0, 1.0)
axes[0, 0].set_yticks(y_ticks)

df["context_recall"].plot(kind="bar", ax=axes[0, 1], title="Context Recall", color="lightgreen")
axes[0, 1].set_ylim(0.0, 1.0)
axes[0, 1].set_yticks(y_ticks)

df["faithfulness"].plot(kind="bar", ax=axes[1, 0], title="Faithfulness", color="salmon")
axes[1, 0].set_ylim(0.0, 1.0)
axes[1, 0].set_yticks(y_ticks)

df["answer_relevancy"].plot(kind="bar", ax=axes[1, 1], title="Answer Relevancy", color="gold")
axes[1, 1].set_ylim(0.0, 1.0)
axes[1, 1].set_yticks(y_ticks)

# 設置標籤
for ax in axes.flat:
    ax.set_xlabel("Run")
    ax.set_ylabel("Score")
    ax.set_xticks(np.arange(0, 10))

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# 假設 df 是你已經生成的 DataFrame

# 提取第一次問答的數據
first_run = df.iloc[0]  # 提取 DataFrame 的第一行

# 分別獲取第一次問答的 context_precision, context_recall, faithfulness, answer_relevancy
context_precision = first_run["context_precision"]
context_recall = first_run["context_recall"]
faithfulness = first_run["faithfulness"]
answer_relevancy = first_run["answer_relevancy"]

# 打印結果
print("First Run Results:")
print(f"Context Precision: {context_precision}")
print(f"Context Recall: {context_recall}")
print(f"Faithfulness: {faithfulness}")
print(f"Answer Relevancy: {answer_relevancy}")
# Out:
# First Run Results:
# Context Precision: 0.999999999975
# Context Recall: 1.0
# Faithfulness: 0.0
# Answer Relevancy: 0.7490150641918119

# %%
# 提取第一次問答的數據並進行可視化
first_run = df.iloc[0]  # 提取 DataFrame 的第一行

# 分別獲取第一次問答的 context_precision, context_recall, faithfulness, answer_relevancy
context_precision = first_run["context_precision"]
context_recall = first_run["context_recall"]
faithfulness = first_run["faithfulness"]
answer_relevancy = first_run["answer_relevancy"]

# 將數據轉換為列表進行可視化
metrics = ["Context Precision", "Context Recall", "Faithfulness", "Answer Relevancy"]
scores = [context_precision, context_recall, faithfulness, answer_relevancy]

# 創建條形圖
plt.figure(figsize=(8, 6))
plt.bar(metrics, scores, color=["skyblue", "lightgreen", "salmon", "gold"])

# 添加標題和標籤
plt.title("first 1", fontsize=16)
plt.xlabel("Metrics", fontsize=12)
plt.ylabel("Scores", fontsize=12)

# 顯示每個條形圖上的分數
for i, v in enumerate(scores):
    plt.text(i, v + 0.01, f"{v:.2f}", ha="center", fontsize=12)

# 顯示圖表
plt.tight_layout()
plt.show()

# %%
for i in range(1,10):
        # 提取第一次問答的數據並進行可視化
    first_run = df.iloc[i]  # 提取 DataFrame 的第一行

    # 分別獲取第一次問答的 context_precision, context_recall, faithfulness, answer_relevancy
    context_precision = first_run["context_precision"]
    context_recall = first_run["context_recall"]
    faithfulness = first_run["faithfulness"]
    answer_relevancy = first_run["answer_relevancy"]

    # 將數據轉換為列表進行可視化
    metrics = ["Context Precision", "Context Recall", "Faithfulness", "Answer Relevancy"]
    scores = [context_precision, context_recall, faithfulness, answer_relevancy]

    # 創建條形圖
    plt.figure(figsize=(8, 6))
    plt.bar(metrics, scores, color=["skyblue", "lightgreen", "salmon", "gold"])

    # 添加標題和標籤
    plt.title(f"first{i}", fontsize=16)
    plt.xlabel("Metrics", fontsize=12)
    plt.ylabel("Scores", fontsize=12)

    # 顯示每個條形圖上的分數
    for i, v in enumerate(scores):
        plt.text(i, v + 0.01, f"{v:.2f}", ha="center", fontsize=12)

    # 顯示圖表
    plt.tight_layout()
    plt.show()

# %%
json_output = df.to_json(orient='records', force_ascii=False)
print(json_output)
# Out:
# [{"user_input":"為預防消費糾紛,保護消費者權益,中央主管機關得選擇特定行業,擬訂其定型化契約應記載或不得記載事項,報請行政院核定後公告,下列敘述何者錯誤?(A)公告不得記載之事項,經記載於定型化契約,仍構成契約之內容(B)違反公告之定型化契約,其定型化契約條款無效(C)公告應記載之事項,雖未記載於定型化契約,仍構成契約之內容(D)企業經營者使用定型化契約者,主管機關得隨時派員查核","retrieved_contexts":["中央主管機關為預防消費糾紛，保護消費者權益，促進定型化契約之公平化，得選擇特定行業，擬訂其定\n\n型化契約應記載或不得記載事項，報請行政院核定後公告之。\n\n前項應記載事項，依契約之性質及目的，其內容得包括：\n\n一、契約之重要權利義務事項。\n\n二、違反契約之法律效果。\n\n三、預付型交易之履約擔保。\n\n四、契約之解除權、終止權及其法律效果。\n\n五、其他與契約履行有關之事項。\n\n第一項不得記載事項，依契約之性質及目的，其內容得包括：\n\n一、企業經營者保留契約內容或期限之變更權或解釋權。\n\nhttps:\/\/www.ey.gov.tw\/Page\/4FF303AE95592945\/f65a641d-d096-48c1-b357-435ac7786e72\n\n4\/13\n\n2024\/8\/25 下午3:18\n\n消費者保護法 (行政院全球資訊網-主管法規)\n\n二、限制或免除企業經營者之義務或責任。\n\n三、限制或剝奪消費者行使權利，加重消費者之義務或責任。\n\n四、其他對消費者顯失公平事項。\n\n違反第一項公告之定型化契約，其定型化契約條款無效。該定型化契約之效力，依前條規定定之。\n\n中央主管機關公告應記載之事項，雖未記載於定型化契約，仍構成契約之內容。\n\n企業經營者使用定型化契約者，主管機關得隨時派員查核。\n\n第十七條之一（企業經營者符合規定之舉證責任）","中央主管機關為預防消費糾紛，保護消費者權益，促進定型化契約之公平化，得選擇特定行業，擬訂其定\n\n型化契約應記載或不得記載事項，報請行政院核定後公告之。\n\n前項應記載事項，依契約之性質及目的，其內容得包括：\n\n一、契約之重要權利義務事項。\n\n二、違反契約之法律效果。\n\n三、預付型交易
# ...

# %%
df.to_json('output.json', orient='records', force_ascii=False)

print("JSON 檔案已成功儲存！")
# Out:
# JSON 檔案已成功儲存！

# %%
df.to_json('output.json', orient='columns', force_ascii=False)

print("JSON 檔案已成功儲存！")
# Out:
# JSON 檔案已成功儲存！

# %%
import os
from ragas import evaluate
from ragas.metrics import (
    faithfulness,
    answer_relevancy,
    context_recall,
    context_precision,
    # context_entity_recall,
    # answer_correctness,
    answer_similarity

)

 
result = evaluate(
    dataset = dataset, 
    metrics=[
        context_precision,
        context_recall,
        faithfulness,
        answer_relevancy,    
        # context_entity_recall,
        # answer_correctness,
        answer_similarity
    ],
)
# Out:
# Evaluating:   0%|          | 0/50 [00:00<?, ?it/s]
# D:\RAGAS\ragas\src\ragas\metrics\base.py:281: DeprecationWarning: The function _single_turn_ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextRecall instead.
#   self._single_turn_ascore(sample=sample, callbacks=group_cm),
# D:\RAGAS\ragas\src\ragas\metrics\base.py:281: DeprecationWarning: The function _single_turn_ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextRecall instead.
#   self._single_turn_ascore(sample=sample, callbacks=group_cm),
# D:\RAGAS\ragas\src\ragas\metrics\base.py:281: DeprecationWarning: The function _single_turn_ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextRecall instead.
#   self._single_turn_ascore(sample=sample, callbacks=group_cm),
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

 
df = result.to_pandas()
df
# Out:
#                                           user_input  \
# 0  為預防消費糾紛,保護消費者權益,中央主管機關得選擇特定行業,擬訂其定型化契約應記載或不得記載...
# 1  依消費者保護法規定,下列關於企業經營者提供商品之敘述,何者正確?(A)對於有危害消費者財產之...
# 2  依消費者保護法規定,企業經營者以定型化契約條款使消費者拋棄消費者審閱之合理期間,其契約條款之...
# 3  依消費者保護法規定,下列有關消費者保護團體之敘述,何者錯誤?(A)消費者保護團體以社團法人或...
# 4  依消費者保護法規定關於商品標示,下列敘述何者錯誤?(A)企業經營者應依商品標示法等法令為商品...
# 5  依消費者保護法規定,企業經營者所出具之書面保證書其應載明事項,下列何者錯誤?(A)交易日期(...
# 6  依消費者保護法規定,下列有關消費者保護團體從事檢驗之敘述,何者錯誤?(A)得委託設有與檢驗項...
# 7  依消費者保護法規定,有關消費關係之定義,下列敘述何者正確?(A)指消費者與消費者間就商品所發...
# 8  依消費者保護法規定,下列關於定型化契約條款之敘述,何者錯誤?(A)定型化契約條款未經記載於定...
# 9  依消費者保護法規定,提供之商品或服務具有危害消費者健康、財產之可能者,下列何者應於明顯處為警...
#
#                                   retrieved_contexts  \
# 0  [中央主管機關為預防消費糾紛，保護消費者權益，促進定型化契約之公平化，得選擇特定行業，擬訂其...
# 1  [Q:028.企業經營者依消費者保護法第七條第三項規定對消費者或第三人之損害賠償責任，得否預...
# 2  [（三）違反合理審閱期間之效力：企業經營者如違反有關合理審閱期間之規定者，由於影響消費者無法...
# 3  [輸入之商品或服務在原產地附有警告標示者，準用前項之規定。\n\n第二十五條（書面保證書及其...
# 4  [企業經營者應確保廣告內容之真實，其對消費者所負之義務不得低於廣告之內容。\n\n企業經營者...
# 5  [（三）廣告代理業：依照公平交易法第二十一條第四項規定，廣告代理業在明知或可得知的情況下，仍...
# ...

# %%
import os
from ragas import evaluate
from ragas.metrics import (
    faithfulness,
    answer_relevancy,
    context_recall,
    context_precision,
    context_entity_recall,
    # answer_correctness,
    answer_similarity

)

 
result = evaluate(
    dataset = dataset, 
    metrics=[
        context_precision,
        context_recall,
        faithfulness,
        answer_relevancy,    
        context_entity_recall,
        # answer_correctness,
        answer_similarity
    ],
)
# Out:
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]
# D:\RAGAS\ragas\src\ragas\metrics\base.py:281: DeprecationWarning: The function _single_turn_ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextRecall instead.
#   self._single_turn_ascore(sample=sample, callbacks=group_cm),
# D:\RAGAS\ragas\src\ragas\metrics\base.py:281: DeprecationWarning: The function _single_turn_ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextRecall instead.
#   self._single_turn_ascore(sample=sample, callbacks=group_cm),
# D:\RAGAS\ragas\src\ragas\metrics\_context_precision.py:147: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

 
df = result.to_pandas()
df
# Out:
#                                           user_input  \
# 0  為預防消費糾紛,保護消費者權益,中央主管機關得選擇特定行業,擬訂其定型化契約應記載或不得記載...
# 1  依消費者保護法規定,下列關於企業經營者提供商品之敘述,何者正確?(A)對於有危害消費者財產之...
# 2  依消費者保護法規定,企業經營者以定型化契約條款使消費者拋棄消費者審閱之合理期間,其契約條款之...
# 3  依消費者保護法規定,下列有關消費者保護團體之敘述,何者錯誤?(A)消費者保護團體以社團法人或...
# 4  依消費者保護法規定關於商品標示,下列敘述何者錯誤?(A)企業經營者應依商品標示法等法令為商品...
# 5  依消費者保護法規定,企業經營者所出具之書面保證書其應載明事項,下列何者錯誤?(A)交易日期(...
# 6  依消費者保護法規定,下列有關消費者保護團體從事檢驗之敘述,何者錯誤?(A)得委託設有與檢驗項...
# 7  依消費者保護法規定,有關消費關係之定義,下列敘述何者正確?(A)指消費者與消費者間就商品所發...
# 8  依消費者保護法規定,下列關於定型化契約條款之敘述,何者錯誤?(A)定型化契約條款未經記載於定...
# 9  依消費者保護法規定,提供之商品或服務具有危害消費者健康、財產之可能者,下列何者應於明顯處為警...
#
#                                   retrieved_contexts  \
# 0  [中央主管機關為預防消費糾紛，保護消費者權益，促進定型化契約之公平化，得選擇特定行業，擬訂其...
# 1  [Q:028.企業經營者依消費者保護法第七條第三項規定對消費者或第三人之損害賠償責任，得否預...
# 2  [（三）違反合理審閱期間之效力：企業經營者如違反有關合理審閱期間之規定者，由於影響消費者無法...
# 3  [輸入之商品或服務在原產地附有警告標示者，準用前項之規定。\n\n第二十五條（書面保證書及其...
# 4  [企業經營者應確保廣告內容之真實，其對消費者所負之義務不得低於廣告之內容。\n\n企業經營者...
# 5  [（三）廣告代理業：依照公平交易法第二十一條第四項規定，廣告代理業在明知或可得知的情況下，仍...
# ...

# %%
df.to_json('output.json', orient='records', force_ascii=False)

print("JSON 檔案已成功儲存！")
# Out:
# JSON 檔案已成功儲存！

# %%
df.to_json('output.json', orient='records', force_ascii=False)

print("JSON 檔案已成功儲存！")
# Out:
# JSON 檔案已成功儲存！

# %%
df = pd.DataFrame(data)

# 將 DataFrame 輸出為 Excel 檔案
df.to_excel('output.xlsx', index=False)

print("Excel 檔案已成功儲存！")
# Out:
# Excel 檔案已成功儲存！

# %%
df = result.to_pandas()
df
# Out:
#                                           user_input  \
# 0  為預防消費糾紛,保護消費者權益,中央主管機關得選擇特定行業,擬訂其定型化契約應記載或不得記載...
# 1  依消費者保護法規定,下列關於企業經營者提供商品之敘述,何者正確?(A)對於有危害消費者財產之...
# 2  依消費者保護法規定,企業經營者以定型化契約條款使消費者拋棄消費者審閱之合理期間,其契約條款之...
# 3  依消費者保護法規定,下列有關消費者保護團體之敘述,何者錯誤?(A)消費者保護團體以社團法人或...
# 4  依消費者保護法規定關於商品標示,下列敘述何者錯誤?(A)企業經營者應依商品標示法等法令為商品...
# 5  依消費者保護法規定,企業經營者所出具之書面保證書其應載明事項,下列何者錯誤?(A)交易日期(...
# 6  依消費者保護法規定,下列有關消費者保護團體從事檢驗之敘述,何者錯誤?(A)得委託設有與檢驗項...
# 7  依消費者保護法規定,有關消費關係之定義,下列敘述何者正確?(A)指消費者與消費者間就商品所發...
# 8  依消費者保護法規定,下列關於定型化契約條款之敘述,何者錯誤?(A)定型化契約條款未經記載於定...
# 9  依消費者保護法規定,提供之商品或服務具有危害消費者健康、財產之可能者,下列何者應於明顯處為警...
#
#                                   retrieved_contexts  \
# 0  [中央主管機關為預防消費糾紛，保護消費者權益，促進定型化契約之公平化，得選擇特定行業，擬訂其...
# 1  [Q:028.企業經營者依消費者保護法第七條第三項規定對消費者或第三人之損害賠償責任，得否預...
# 2  [（三）違反合理審閱期間之效力：企業經營者如違反有關合理審閱期間之規定者，由於影響消費者無法...
# 3  [輸入之商品或服務在原產地附有警告標示者，準用前項之規定。\n\n第二十五條（書面保證書及其...
# 4  [企業經營者應確保廣告內容之真實，其對消費者所負之義務不得低於廣告之內容。\n\n企業經營者...
# 5  [（三）廣告代理業：依照公平交易法第二十一條第四項規定，廣告代理業在明知或可得知的情況下，仍...
# ...

# %%
df.to_excel('out.xlsx', index=False)

print("Excel 檔案已成功儲存！")
# Out:
# Excel 檔案已成功儲存！

# %%
import matplotlib.pyplot as plt


# 創建 3x2 的子圖佈局
fig, axes = plt.subplots(3, 2, figsize=(12, 15))
fig.suptitle("Evaluation Metrics Over 10 Runs", fontsize=16)

# 設置 x 軸範圍為 1 到 10
x_range = range(1, 11)

# 繪製每個特性的折線圖
df["context_precision"].plot(ax=axes[0, 0], title="Context Precision", color="skyblue", xticks=x_range)
df["context_recall"].plot(ax=axes[0, 1], title="Context Recall", color="lightgreen", xticks=x_range)
df["faithfulness"].plot(ax=axes[1, 0], title="Faithfulness", color="salmon", xticks=x_range)
df["answer_relevancy"].plot(ax=axes[1, 1], title="Answer Relevancy", color="gold", xticks=x_range)
df["context_entity_recall"].plot(ax=axes[2, 0], title="Context Entity Recall", color="lightcoral", xticks=x_range)
df["semantic_similarity"].plot(ax=axes[2, 1], title="Semantic Similarity", color="lightblue", xticks=x_range)

# 設置標籤
for ax in axes.flat:
    ax.set_xlabel("Run")
    ax.set_ylabel("Score")

# 調整佈局，使圖表不會重疊
plt.tight_layout(rect=[0, 0, 1, 0.96])

# 顯示圖表
plt.show()
